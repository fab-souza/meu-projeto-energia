# %%
import pandas as pd

# %%
dados_epe = pd.read_excel(
    io = '/content/Matriz ab2021.xlsx',
    header = [2,3,4]
)
dados_epe
# Out:
#                                                  FLUXO      PETRÓ_  GÁS NAT.  \
#                                                 BRASIL         LEO     ÚMIDO
#                                     Unnamed: 0_level_2      mil m3   milh m3
# 0                                             PRODUÇÃO  168783.516  48818.75
# 1                                           IMPORTAÇÃO    8133.621         0
# 2                                 VARIAÇÃO DE ESTOQUES    -345.976         0
# 3                       OFERTA TOTAL                    176571.161  48818.75
# 4                                           EXPORTAÇÃO  -72640.239         0
# ..                                                 ...         ...       ...
# 242                            CARVÃO MINERAL & OUTROS           0         0
# 243                             CONSUMO NÃO ENERGÉTICO           0         0
# 244                           MATÉRIA PRIMA DA QUÍMICA           0         0
# ...

# %%
dados_epe.sample(6)
# Out:
#                               FLUXO PETRÓ_ GÁS NAT.             C.VAPOR        \
#                              BRASIL    LEO    ÚMIDO        SECO    3100  3300
#                  Unnamed: 0_level_2 mil m3  milh m3     milh m3   mil t mil t
# 168                          TÊXTIL      0        0  179.523862       0     0
# 73                          QUÍMICA      0        0  463.583214       0     0
# 143  CARVOARIAS                          0        0           0       0     0
# 202                          TÊXTIL      0        0    3.263589       0     0
# 163                     FERRO LIGAS      0        0    2.921673       0     0
# 5                   NÃO APROVEITADA      0    -1200       -33.7       0     0
#
#                                  ...              Biogás            Biomassa  \
#      3700  4200  4500      4700  ... Unnamed: 58_level_1 Unnamed: 59_level_1
#     mil t mil t mil t     mil t  ...             mil tep             mil tep
# ...

# %%
dados_aneel = pd.read_csv(
    filepath_or_buffer = '/content/siga-empreendimentos-geracao.csv',
    encoding = "ISO-8859-1", sep=';',
    on_bad_lines='skip',
    header = [0]
)
dados_aneel
# Out:
#       DatGeracaoConjuntoDados NomEmpreendimento  IdeNucleoCEG  \
# 0                  2022-11-01                 E             8
# 1                  2022-11-01                 F             9
# 2                  2022-11-01                 G            10
# 3                  2022-11-01       14 de Julho            12
# 4                  2022-11-01            Abaúna            15
# ...                       ...               ...           ...
# 23078              2022-11-01             10546         70676
# 23079              2022-11-01             10547         70677
# 23080              2022-11-01             10548         70678
# 23081              2022-11-01             10549         70679
# 23082              2022-11-01             10544         70680
#
#                      CodCEG SigUFPrincipal SigTipoGeracao DscFaseUsina  \
# 0      PCH.PH.MG.000008-6.1             MG            PCH     Operação
# 1      PCH.PH.MG.000009-4.1             MG            PCH     Operação
# ...

# %%
dados_aneel.sample(6)
# Out:
#       DatGeracaoConjuntoDados           NomEmpreendimento  IdeNucleoCEG  \
# 15200              2022-11-01   Ataide Almeida de Freitas         60812
# 12195              2022-11-01   Rosivaldo da Silva Coelho         57017
# 1085               2022-11-01              Santa Lúcia II         28395
# 5520               2022-11-01                   Caetité F         37006
# 6683               2022-11-01   Haroldo Rodrigues Martins         39064
# 2013               2022-11-01  SMTE - Subestação Paracatu         29751
#
#                      CodCEG SigUFPrincipal SigTipoGeracao DscFaseUsina  \
# 15200  UFV.RS.PA.060812-2.1             PA            UFV     Operação
# 12195  UFV.RS.PA.057017-6.1             PA            UFV     Operação
# 1085   PCH.PH.MT.028395-9.1             MT            PCH     Operação
# 5520   EOL.CV.BA.037006-1.1             BA            EOL   Construção
# 6683   UFV.RS.PA.039064-0.1             PA            UFV     Operação
# ...
